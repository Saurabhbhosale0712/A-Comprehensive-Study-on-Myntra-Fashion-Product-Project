# %% [markdown]
# # Cluster product descriptions into similar groups by using NLP techinque

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Gaurav\Desktop\final data NLP.csv")
data
# Out:
#          BrandName               Category Individual_category  \
# 0         Roadster            Bottom Wear               jeans
# 1       LOCOMOTIVE            Bottom Wear         track-pants
# 2         Roadster                Topwear              shirts
# 3           Zivame  Lingerie & Sleep Wear           shapewear
# 4         Roadster                Western             tshirts
# ...            ...                    ...                 ...
# 184908    Roadster                Western             tshirts
# 184909    Roadster                Western             tshirts
# 184910    Roadster                Western             tshirts
# 184911    Roadster                Western             tshirts
# 184912    Roadster                Western             tshirts
#
#        category_by_Gender  OriginalPrice (in Rs)  Discount (in Rs)  \
# 0                     Men                 1499.0            824.45
# 1                     Men                 1149.0            517.05
# 2                     Men                 1399.0            629.55
# 3                   Women                 1295.0            893.55
# 4                   Women                  599.0            389.35
# ...                   ...                    ...               ...
# 184908              Women                  998.0              0.00
# 184909              Women                  998.0              0.00
# 184910              Women                  998.0              0.00
# 184911              Women                  998.0              0.00
# 184912              Women                  999.0              0.00
#
#         Discount (in %)  Ratings  Reviews  \
# 0                    45      3.9      999
# 1                    55      4.0      999
# 2                    55      4.3      999
# 3                    31      4.2      999
# 4                    35      4.2      999
# ...                 ...      ...      ...
# 184908                0      4.1        0
# 184909                0      4.2        0
# 184910                0      4.2        0
# 184911                0      4.2        0
# 184912                0      4.3        0
#
#                                               Description
# 0       roadster men navy blue slim fit mid rise clean...
# 1       locomotive men black  white solid slim fit tra...
# 2       roadster men navy white  black geometric print...
# 3       zivame women black saree shapewear zi3023core0...
# 4       roadster women white solid v neck pure cotton ...
# ...                                                   ...
# 184908      roadster women pack of 2 solid cotton t shirt
# 184909       roadster women set of 2 pure cotton t shirts
# 184910      roadster women pack of 2 solid cotton t shirt
# 184911      roadster women pack of 2 solid cotton t shirt
# 184912  roadster women pack of 2 v neck cotton pure co...
#
# [184913 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

documents = data['Description'].values.astype("U")

vectorizer = TfidfVectorizer(stop_words='english')
features = vectorizer.fit_transform(documents)

# %%
k = 20
model = KMeans(n_clusters=k, init='k-means++', max_iter=100, n_init=1)
model.fit(features)
data['cluster'] = model.labels_
data.head()
# Out:
#     BrandName               Category Individual_category category_by_Gender  \
# 0    Roadster            Bottom Wear               jeans                Men
# 1  LOCOMOTIVE            Bottom Wear         track-pants                Men
# 2    Roadster                Topwear              shirts                Men
# 3      Zivame  Lingerie & Sleep Wear           shapewear              Women
# 4    Roadster                Western             tshirts              Women
#
#    OriginalPrice (in Rs)  Discount (in Rs)  Discount (in %)  Ratings  Reviews  \
# 0                 1499.0            824.45               45      3.9      999
# 1                 1149.0            517.05               55      4.0      999
# 2                 1399.0            629.55               55      4.3      999
# 3                 1295.0            893.55               31      4.2      999
# 4                  599.0            389.35               35      4.2      999
#
#                                          Description  cluster
# 0  roadster men navy blue slim fit mid rise clean...        6
# 1  locomotive men black  white solid slim fit tra...       17
# 2  roadster men navy white  black geometric print...       16
# 3  zivame women black saree shapewear zi3023core0...       18
# 4  roadster women white solid v neck pure cotton ...        4

# %%
# output the result to a text file.

clusters = data.groupby('cluster')    

for cluster in clusters.groups:
    f = open('cluster'+str(cluster)+ '.csv', 'w') # create csv file
    data = clusters.get_group(cluster)[['Individual_category','Description']] # get title and overview columns
    f.write(data.to_csv(index_label='id')) # set index to id
    f.close()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
print("Cluster centroids: \n")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms  = vectorizer.get_feature_names_out()

for i in range(k):
    print("Cluster %d:" % i)
    for j in order_centroids[i, :10]: #print out 10 feature terms of each cluster
        print (' %s' % terms[j])
    print('------------')
# Out:
# Cluster centroids:
#
# Cluster 0:
#  kurta
#  straight
#  women
#  printed
#  white
#  men
#  palazzos
#  design
#  blue
#  dupatta
# ------------
# Cluster 1:
#  night
#  suit
#  printed
#  women
#  white
#  blue
#  pink
#  black
#  cotton
#  navy
# ------------
# Cluster 2:
#  cotton
#  pure
#  shirt
#  polo
#  collar
#  men
#  printed
#  white
#  blue
#  women
# ------------
# Cluster 3:
#  joggers
#  solid
#  men
#  fit
#  black
#  slim
#  grey
#  women
#  blue
#  navy
# ------------
# Cluster 4:
#  neck
#  round
#  shirt
#  printed
#  cotton
#  men
#  pure
#  women
#  solid
#  black
# ------------
# Cluster 5:
#  jacket
#  solid
#  nehru
#  men
#  women
#  denim
#  bomber
#  blue
#  tailored
#  padded
# ------------
# Cluster 6:
#  jeans
#  stretchable
#  rise
#  fit
#  clean
#  look
#  blue
#  mid
#  fade
#  skinny
# ------------
# Cluster 7:
#  bra
#  non
#  padded
#  wired
#  lightly
#  everyday
#  zivame
#  underwired
#  solid
#  shirt
# ------------
# Cluster 8:
#  ethnic
#  motifs
#  kurta
#  printed
#  women
#  cotton
#  sangria
#  pure
#  white
#  blue
# ------------
# Cluster 9:
#  length
#  leggings
#  ankle
#  socks
#  pack
#  solid
#  churidar
#  women
#  tag
#  birds
# ------------
# Cluster 10:
#  dress
#  line
#  women
#  maxi
#  solid
#  flare
#  midi
#  black
#  printed
#  blue
# ------------
# Cluster 11:
#  fit
#  regular
#  trousers
#  men
#  slim
#  solid
#  shorts
#  formal
#  blue
#  chinos
# ------------
# Cluster 12:
#  pack
#  briefs
#  shirts
#  women
#  cotton
#  assorted
#  solid
#  men
#  pure
#  roadster
# ------------
# Cluster 13:
#  sweatshirt
#  hooded
#  women
#  solid
#  men
#  printed
#  black
#  roadster
#  colourblocked
#  green
# ------------
# Cluster 14:
#  hrx
#  roshan
#  hrithik
#  rapid
#  dry
#  men
#  lifestyle
#  training
#  running
#  bio
# ------------
# Cluster 15:
#  talkies
#  tokyo
#  women
#  dress
#  solid
#  blue
#  black
#  fit
#  green
#  trousers
# ------------
# Cluster 16:
#  casual
#  shirt
#  fit
#  slim
#  men
#  checked
#  blue
#  white
#  regular
#  opaque
# ------------
# Cluster 17:
#  pants
#  track
#  lounge
#  solid
#  men
#  women
#  black
#  grey
#  blue
#  fit
# ------------
# Cluster 18:
#  women
#  solid
#  black
#  printed
#  blue
#  white
#  saree
#  pink
#  green
#  shirt
# ------------
# Cluster 19:
#  floral
#  dress
#  printed
#  print
#  women
#  white
#  kurta
#  pink
#  line
#  blue
# ------------
